# %%
num =[20,30,40,50,33]
squared =[x**2 for x in num if x%2!=0]
squared
# Out:
# [1089]

# %%
tup =(5,6)
tup
# Out:
# (5, 6)

# %%
x,y,z=(20,30,50)
print (x)
y
z
# Out:
# 20
# 50

# %%
a,_,b= (2,3,4)
a,_,b
print(_)
# Out:
# 3

# %% [markdown]
# set

# %%
s={2,3,4}
s.add(5)
s
# Out:
# {2, 3, 4, 5}

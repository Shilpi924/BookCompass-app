# %% [markdown]
# Part 6: Practice Problem – Student Scores
# Given:
# python
# scores = [78, 85, 62, 90, 56, 99, 74]
# Write code to:
# Calculate and print the average score.
# Print all scores greater than 80.
# Replace scores below 60 with the word "Fail"

# %%
scores = [78, 85, 62, 90, 56, 99, 74]
avg=0
for n in scores:
    avg+=n
avg/len(scores)
# Out:
# 77.71428571428571

# %%
scores = [78, 85, 62, 90, 56, 99, 74]
print([x for x in scores if(x>80)])
# Out:
# [85, 90, 99]

# %%
scores = [78, 85, 62, 90, 56, 99, 74]
for score in scores:
    if(score<60):
        scores[3].replace("fail")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 4
#       2 for score in scores:
#       3     if(score<60):
# ----> 4         scores[3].replace("fail")
#
# AttributeError: 'int' object has no attribute 'replace'

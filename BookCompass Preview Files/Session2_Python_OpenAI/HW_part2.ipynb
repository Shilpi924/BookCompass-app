# %% [markdown]
# Part 2: Basic List Operations
# Write Python code to:
# Create a list of 5 of your favorite fruits.
# Print the first and last items using indexing.
# Add a new fruit to the list.
# Remove the third item.
# Sort the list alphabetically.

# %%
fav_fruits = ["Grapes", "Mango", "Banana", "Guava","Pomegranate"]
fav_fruits.append("Apple")
fav_fruits.pop(2)
fav_fruits.sort()
fav_fruits
# Out:
# ['Apple', 'Grapes', 'Guava', 'Mango', 'Pomegranate']

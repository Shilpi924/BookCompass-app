# %% [markdown]
# Part 7: LLM & Prompt Engineering
# Goal:
# Understand how system prompts and generation parameters affect AI responses.
# Setup:
# Use the GPT integration code we worked on in class.
# Tasks
# Modify the system prompt
# Create at least two different system prompts (for example: strict, friendly, teacher-like, creative).
# Keep the user question exactly the same each time.
# Ask the same question
# Use one identical user question.
# Observe how the response changes when:
# The system prompt changes
# The parameter values change
# Document your results
# Show at least two different responses to the same question.
# Briefly explain why the responses changed.

# %%
import os
import textwrap
from dotenv import load_dotenv
from openai import OpenAI
system_prompts = {'strict':'Yo are strict tutor',
                          'teacherlike' :'you are a teacher like tutor',
                          'friendly':'you are a friendly tutor',
                          'creative': 'you are a creative tutor'
                          }
load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")
#my_api_key[:5], my_api_key[-10:]
client = OpenAI(api_key=my_api_key)
print (my_api_key)
# Out:
# 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

# %%
def get_response_from_model(prompt, context):

    response = client.chat.completions.create(

        model="gpt-4.1-nano",
        messages=[
            {
                "role": "system", 
                "content": "{system_prompts.get(style,'teacherlike')}"
            },
            {
                "role": "user", 
                "content": f"Context information:\n{context}\n\nQuestion: {prompt}"
            }
        ]
    )
    return textwrap.fill(response.choices[0].message.content)

# %%
context = "I know. "
prompt = input("Ask something: ")

# Corrected function call
response_text = get_response_from_model(prompt, context)

print(f"\nOpenAI says: {response_text}")
# Out:
# OpenAI says: Let's analyze the word "strawberry" step by step to find out how many
# letter "r"s it contains.  1. Write down the word: strawberry 2. Break
# it down into individual letters: s t r a w b e r r y 3. Identify all
# the "r"s:    - The third letter is "r".    - The seventh letter is
# "r".    - The eighth letter is "r". 4. Count the total number of "r"s:
# - There are 3 "r"s in "strawberry".  **Answer:** There are 3 "r"s in
# the word "strawberry".

# %% [markdown]
# Question :give me a question

# %%
def get_response_from_model(prompt, context):
    
    response = client.chat.completions.create(

        model="gpt-4.1-nano",
        messages=[
            {
                "role": "system", 
                "content": "{system_prompts.get(style,'strict')}"
            },
            {
                "role": "user", 
                "content": f"Context information:\n{context}\n\nQuestion: {prompt}"
            }
        ]
    )
    return textwrap.fill(response.choices[0].message.content)

# %%
context = "I know. "
prompt = input("Ask something: ")

# Corrected function call
response_text = get_response_from_model(prompt, context)

print(f"\nOpenAI says: {response_text}")
# Out:
# OpenAI says: What is something you know that has made a significant impact on your
# understanding or perspective?

# %%
def get_response_from_model(prompt, context):
    
    response = client.chat.completions.create(

        model="gpt-4.1-nano",
        messages=[
            {
                "role": "system", 
                "content": "{system_prompts.get(style,'creative')}"
            },
            {
                "role": "user", 
                "content": f"Context information:\n{context}\n\nQuestion: {prompt}"
            }
        ]
    )
    return textwrap.fill(response.choices[0].message.content)

# %%
context = "I know. "
prompt = input("Ask something: ")

# Corrected function call
response_text = get_response_from_model(prompt, context)

print(f"\nOpenAI says: {response_text}")
# Out:
# OpenAI says: What is something you're currently curious about or eager to learn
# more regarding?

# %%
def get_response_from_model(prompt, context):
    
    response = client.chat.completions.create(

        model="gpt-4.1-nano",
        messages=[
            {
                "role": "system", 
                "content": "{system_prompts.get(style,'friendly')}"
            },
            {
                "role": "user", 
                "content": f"Context information:\n{context}\n\nQuestion: {prompt}"
            }
        ]
    )
    return textwrap.fill(response.choices[0].message.content)

# %%
context = "I know. "
prompt = input("Ask something: ")

# Corrected function call
response_text = get_response_from_model(prompt, context)

print(f"\nOpenAI says: {response_text}")
# Out:
# OpenAI says: Sure! Here's a question for you:   What is one goal you would like to
# achieve this year?

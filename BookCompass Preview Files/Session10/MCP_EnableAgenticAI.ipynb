# %%
# %pip install FASTMCP
# Out:
# Requirement already satisfied: FASTMCP in /opt/anaconda3/lib/python3.13/site-packages (3.4.2)
# Requirement already satisfied: fastmcp-slim==3.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (3.4.2)
# Requirement already satisfied: platformdirs>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim==3.4.2->fastmcp-slim[client,server]==3.4.2->FASTMCP) (4.5.0)
# Requirement already satisfied: pydantic-settings>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim==3.4.2->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2.12.0)
# Requirement already satisfied: pydantic>=2.11.7 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic[email]>=2.11.7->fastmcp-slim==3.4.2->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2.12.4)
# Requirement already satisfied: python-dotenv>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim==3.4.2->fastmcp-slim[client,server]==3.4.2->FASTMCP) (1.1.0)
# Requirement already satisfied: rich>=13.9.4 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim==3.4.2->fastmcp-slim[client,server]==3.4.2->FASTMCP) (14.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim==3.4.2->fastmcp-slim[client,server]==3.4.2->FASTMCP) (4.15.0)
# Requirement already satisfied: authlib>=1.6.11 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (1.7.2)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (1.3.1)
# Requirement already satisfied: httpx<1.0,>=0.28.1 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.28.1)
# Requirement already satisfied: mcp<2.0,>=1.24.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (1.27.2)
# Requirement already satisfied: opentelemetry-api>=1.20.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (1.42.1)
# Requirement already satisfied: py-key-value-aio<0.5.0,>=0.4.4 in /opt/anaconda3/lib/python3.13/site-packages (from py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4; extra == "client"->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.4.5)
# Requirement already satisfied: starlette>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (1.2.1)
# Requirement already satisfied: cyclopts>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (4.16.1)
# Requirement already satisfied: griffelib>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (2.0.2)
# Requirement already satisfied: joserfc>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (1.7.0)
# Requirement already satisfied: jsonref>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (1.1.0)
# Requirement already satisfied: jsonschema-path>=0.3.4 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.5.0)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.5.1)
# Requirement already satisfied: packaging>=24.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (25.0)
# Requirement already satisfied: pyperclip>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (1.11.0)
# Requirement already satisfied: python-multipart>=0.0.26 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.0.32)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (6.0.3)
# Requirement already satisfied: uncalled-for>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.3.2)
# Requirement already satisfied: uvicorn>=0.35 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.49.0)
# Requirement already satisfied: watchfiles>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (1.2.0)
# Requirement already satisfied: websockets>=15.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from fastmcp-slim[client,server]==3.4.2->FASTMCP) (16.0)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0,>=0.28.1->fastmcp-slim[client,server]==3.4.2->FASTMCP) (4.10.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0,>=0.28.1->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0,>=0.28.1->fastmcp-slim[client,server]==3.4.2->FASTMCP) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0,>=0.28.1->fastmcp-slim[client,server]==3.4.2->FASTMCP) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0,>=0.28.1->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.16.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/anaconda3/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/anaconda3/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp-slim[client,server]==3.4.2->FASTMCP) (4.25.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/anaconda3/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0,>=1.24.0->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2.10.1)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/anaconda3/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp-slim[client,server]==3.4.2->FASTMCP) (3.4.4)
# Requirement already satisfied: typing-inspection>=0.4.1 in /opt/anaconda3/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.4.2)
# Requirement already satisfied: beartype>=0.20.0 in /opt/anaconda3/lib/python3.13/site-packages (from py-key-value-aio<0.5.0,>=0.4.4->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4; extra == "client"->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.22.9)
# Requirement already satisfied: aiofile>=3.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4; extra == "client"->fastmcp-slim[client,server]==3.4.2->FASTMCP) (3.11.1)
# Requirement already satisfied: keyring>=25.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4; extra == "client"->fastmcp-slim[client,server]==3.4.2->FASTMCP) (25.7.0)
# Requirement already satisfied: cachetools>=5.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4; extra == "client"->fastmcp-slim[client,server]==3.4.2->FASTMCP) (5.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp-slim==3.4.2->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp-slim==3.4.2->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2.41.5)
# Requirement already satisfied: caio~=0.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiofile>=3.5.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4; extra == "client"->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.9.25)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio->httpx<1.0,>=0.28.1->fastmcp-slim[client,server]==3.4.2->FASTMCP) (1.3.0)
# Requirement already satisfied: cryptography in /opt/anaconda3/lib/python3.13/site-packages (from authlib>=1.6.11->fastmcp-slim[client,server]==3.4.2->FASTMCP) (46.0.3)
# Requirement already satisfied: attrs>=23.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from cyclopts>=4.0.0->fastmcp-slim[client,server]==3.4.2->FASTMCP) (25.4.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /opt/anaconda3/lib/python3.13/site-packages (from cyclopts>=4.0.0->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.18.0)
# Requirement already satisfied: rich-rst<3.0.0,>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from cyclopts>=4.0.0->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2.0.1)
# Requirement already satisfied: pygments>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich-rst<3.0.0,>=1.3.1->cyclopts>=4.0.0->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2.19.2)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography->authlib>=1.6.11->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography->authlib>=1.6.11->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2.23)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.24.0->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.24.0->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.24.0->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.28.0)
# Requirement already satisfied: pathable<0.7.0,>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema-path>=0.3.4->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.6.0)
# Requirement already satisfied: jaraco.classes in /opt/anaconda3/lib/python3.13/site-packages (from keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4; extra == "client"->fastmcp-slim[client,server]==3.4.2->FASTMCP) (3.4.0)
# Requirement already satisfied: jaraco.functools in /opt/anaconda3/lib/python3.13/site-packages (from keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4; extra == "client"->fastmcp-slim[client,server]==3.4.2->FASTMCP) (4.1.0)
# Requirement already satisfied: jaraco.context in /opt/anaconda3/lib/python3.13/site-packages (from keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4; extra == "client"->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.0.0)
# Requirement already satisfied: email-validator>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic[email]>=2.11.7->fastmcp-slim==3.4.2->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp-slim==3.4.2->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=13.9.4->fastmcp-slim==3.4.2->fastmcp-slim[client,server]==3.4.2->FASTMCP) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp-slim==3.4.2->fastmcp-slim[client,server]==3.4.2->FASTMCP) (0.1.2)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/lib/python3.13/site-packages (from uvicorn>=0.35->fastmcp-slim[client,server]==3.4.2->FASTMCP) (8.2.1)
# Requirement already satisfied: more_itertools in /opt/anaconda3/lib/python3.13/site-packages (from jaraco.classes->keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4; extra == "client"->fastmcp-slim[client,server]==3.4.2->FASTMCP) (10.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

print(requests.__version__)

# %%
import os
import requests
from dotenv import load_dotenv
from fastmcp import FastMCP

load_dotenv()

app = FastMCP("Library_mcp_app")

load_dotenv(override=True,dotenv_path="../../.env.local")
load_dotenv(override=True,dotenv_path="../../.env.local")
api=os.getenv("GOOGLE_BOOKS_API_KEY")

@app.tool()
def search_books(title: str):
    response = requests.get(
        "https://www.googleapis.com/books/v1/volumes",
        params={
            "q": title,
            "maxResults": 5,
            "key": "AIzaSyA9nO5cCv8TmQLbT0_so3vpwl2kBt_cLGg"
        }
    )

    data = response.json()

    books = []

    for item in data.get("items", []):
        volume = item.get("volumeInfo", {})

        books.append({
            "title": volume.get("title"),
            "authors": volume.get("authors", []),
            "publisher": volume.get("publisher", ""),
            "publishedDate": volume.get("publishedDate", ""),
            "description": volume.get("description", "")[:200]
        })

    return books

# %%
search_books("harry potter")
search_books("python programming")
# Out:
# [{'title': 'Learn to Program with Python 3',
#   'authors': ['Irv Kalb'],
#   'publisher': 'Apress',
#   'publishedDate': '2018-08-22',
#   'description': 'Move from zero knowledge of programming to comfortably writing small to medium-sized programs in Python. Fully updated for Python 3, with code and examples throughout, the book explains Python coding '},
#  {'title': 'Coding',
#   'authors': ['Michael Clark', 'Michael Learn'],
#   'publisher': 'Mikcorp Limited',
#   'publishedDate': '2021-02-06',
#   'description': "55 % discount for bookstores ! Now At $31.99 instead of $ 74,38 Includes 3 manuscripts Learn Python Programming In today's Industry, Python Programming is highly recommended for developing Websites. T"},
#  {'title': 'CODING and PROGRAMMING',
#   'authors': ['John Brown'],
#   'publisher': 'John Brown',
#   'publishedDate': '2021-04-12',
#   'description': '55 % discount for bookstores ! Now At $26.99 instead of $ 41.83 $ Your customers will never stop reading this guide !!! PYTHON PROGRAMMING This book presented the execution model of Python (how Python'},
#  {'title': 'Programming and Coding: This Book Includes JavaScript Programming and Learn Python Programming',
#   'authors': ['Tom Clark'],
#   'publisher': 'JavaScript Programming and Pyt',
#   'publishedDate': '2021-03-19',
#   'description': "55 % discount for bookstores ! Now At $26.99 instead of $ 41.83 $ Your customers will never stop reading this guide !!! JAVASCRIPT In this book, we learned in this discussion that ES6 support isn't un"},
#  {'title': 'Advanced Python Programming',
#   'authors': ['Quan Nguyen'],
#   'publisher': 'Packt Publishing',
#   'publishedDate': '2022-03-25',
#   'description': "Write fast, robust, and highly reusable applications using Python's internal optimization, state-of-the-art performance-benchmarking tools, and cutting-edge libraries Key Features: Benchmark, profile,"}]

# %%
import requests

r = requests.get("https://www.google.com")
print(r.status_code)
# Out:
# 200

# %%
import requests

url = "https://www.googleapis.com/books/v1/volumes?q=harry+potter"
r = requests.get(url)

print(r.status_code)
print(r.text[:500])
# Out:
# 429
# {
#   "error": {
#     "code": 429,
#     "message": "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'books.googleapis.com' for consumer 'project_number:624717413613'.",
#     "errors": [
#       {
#         "message": "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'books.googleapis.com' for consumer 'project_number:624717413613'.",
#         "domain": "global",
#         "reason": "rateLimitExceeded"
#       }
#     ],
#     "status": "RESOURCE_EXH

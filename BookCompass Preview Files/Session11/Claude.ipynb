# %%
# %pip install anthropic python-dotenv
# Out:
# Collecting anthropic
#   Downloading anthropic-0.109.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.13/site-packages (1.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (2.12.4)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Downloading anthropic-0.109.1-py3-none-any.whl (923 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 923.9/923.9 kB 24.1 MB/s  0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.109.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
import anthropic

load_dotenv()
load_dotenv(override=True, dotenv_path="../.env.local")

client = anthropic.Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

def generate(prompt):
    response = client.messages.create(
        model="claude-haiku-4-5",  # cheapest model
        max_tokens=1024,
        messages=[
            {"role": "user", "content": prompt}
        ]
    )
    return response.content[0].text


if __name__ == "__main__":
    prompt = "Tell me a fun fact about space"
    print("Prompt:", prompt)
    print("\nResponse:")
    print(generate(prompt))
# Out:
# Prompt: Tell me a fun fact about space
#
# Response:
# # Fun Space Fact 🚀
#
# A day on Venus is longer than a year on Venus!
#
# Venus takes about 243 Earth days to rotate once on its axis, but only about 225 Earth days to orbit the Sun. So it completes its journey around the Sun faster than it completes a single rotation on itself.
#
# Even weirder: Venus also rotates *backwards* compared to most other planets, making it one of the solar system's true oddities.

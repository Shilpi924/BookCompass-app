# %%
import ollama

def ask_question_local_llm(prompt):
    # print(f"User asked: {prompt}")
    # my_client.chat.completions.create

    # Run a prompt against a local model (e.g., llama2)
    response = ollama.chat(
        model='llama3',
        messages=[
            {"role": "system", "content": "You are a helpful AI assitant - Respond in one line"},
            {"role": "user", "content": prompt}
        ]
    )
    return response['message']['content']

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")

# %%
my_client = OpenAI(api_key=my_api_key)
# my_client

def ask_question_open_gpt_41(prompt):

    # print(f"User asked: {prompt}")
    # my_client.chat.completions.create

    llm_response = my_client.chat.completions.create(
        model="gpt-4.1-nano",
        messages=[
            {"role": "system", "content": "You are a helpful assistant. Answer as concisely as possible."},
            {"role": "user", "content": prompt}
        ]
    )
    return llm_response.choices[0].message.content  


def ask_question_open_gpt_5(prompt):

    # print(f"User asked: {prompt}")
    # my_client.chat.completions.create

    llm_response = my_client.chat.completions.create(
        model="gpt-5-nano",
        messages=[
            {"role": "system", "content": "You are a helpful assistant. Answer as concisely as possible."},
            {"role": "user", "content": prompt}
        ]
    )
    return llm_response.choices[0].message.content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 my_client = OpenAI(api_key=my_api_key)
#       2 # my_client
#       4 def ask_question_open_gpt_41(prompt):
#       5
#       6     # print(f"User asked: {prompt}")
#       7     # my_client.chat.completions.create
#
# NameError: name 'OpenAI' is not defined

# %%
prompt = "What is the capital of France?"

response_local_llm = ask_question_local_llm(prompt)
response_open_ai_41 = ask_question_open_gpt_41(prompt)
response_open_ai_5 = ask_question_open_gpt_5(prompt)

print(f"Response from local LLM: {response_local_llm}")
print(f"Response from OpenAI GPT-4.1: {response_open_ai_41}")
print(f"Response from OpenAI GPT-5: {response_open_ai_5}")
# Out:
# Response from local LLM: The capital of France is Paris.
# Response from OpenAI GPT-4.1: The capital of France is Paris.
# Response from OpenAI GPT-5: Paris.

# %%
import time
while True:
    # Ask user for a question
    user_prompt = input("Ask something: ")

    if (user_prompt.lower() != 'quit'):
        # Get and print the response
        
        print ("\n\n-------------------LOCAL LLM RESPONSE-------------------")
        start = time.time()
        response_local_llm = ask_question_local_llm(user_prompt)
        end = time.time()   
        print(f"Time taken by Local LLM: {end - start} seconds")
        #print("\nLocal LLM says:", response_local)     

        print ("-------------------OPEN AI RESPONSE - GPT-4.1 -------------------")
        start = time.time()
        response_open_ai_41 = ask_question_open_gpt_41(user_prompt)
        end = time.time()   
        print(f"Time taken by OpenAI: {end - start} seconds")
       # print("\nOpenAI says:", response_openai)

        print ("\n\n-------------------OPEN AI RESPONSE - GPT-5 -------------------")
        start = time.time()
        response_open_ai_5 = ask_question_open_gpt_5(user_prompt)
        end = time.time()
        print(f"Time taken by OpenAI GPT-5: {end - start} seconds")
        #print("\nOpenAI GPT-5 says:", response_openai_5)

           

        # add delay of 3 seconds
        time.sleep(3)
    else:
        print("Exiting...")
        break   
def compare_responses():
    comparison_response = my_client.chat.completions.create(
        model="gpt-5-nano",
        messages=[
            {"role": "system", "content": '''You are an evaluator. Please evaluate the quality of the response by different models.
            Put as a JSON response with keys as model names and values as score out of 10. Also add a justification for the score.'''},
            {"role": "user", "content": "Local LLM response: " + response_local_llm 
            +"\n\nOpenAI GPT-4.1 response: " + response_open_ai_41 
            + "\n\nOpenAI GPT-5 response: " + response_open_ai_5 }
        ]
    )
    return comparison_response.choices[0].message.content
comp = compare_responses()
print(comp)
# Out:
# -------------------LOCAL LLM RESPONSE-------------------
# Time taken by Local LLM: 2.904949188232422 seconds
# -------------------OPEN AI RESPONSE - GPT-4.1 -------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 18
#      16 print ("-------------------OPEN AI RESPONSE - GPT-4.1 -------------------")
#      17 start = time.time()
# ---> 18 response_open_ai_41 = ask_question_open_gpt_41(user_prompt)
#      19 end = time.time()
#      20 print(f"Time taken by OpenAI: {end - start} seconds")
#
# NameError: name 'ask_question_open_gpt_41' is not defined

# %%
def compare_responses():
    comparison_response = my_client.chat.completions.create(
        model="gpt-5-nano",
        messages=[
            {"role": "system", "content": '''You are an evaluator. Please evaluate the quality of the response by different models.
            Put as a JSON response with keys as model names and values as score out of 10. Also add a justification for the score.'''},
            {"role": "user", "content": "Local LLM response: " + response_local_llm 
            +"\n\nOpenAI GPT-4.1 response: " + response_open_ai_41 
            + "\n\nOpenAI GPT-5 response: " + response_open_ai_5 }
        ]
    )
    return comparison_response.choices[0].message.content

# %%
comp = compare_responses()
print(comp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 comp = compare_responses()
#       2 print(comp)
#
# Cell In[7], line 2, in compare_responses()
#       1 def compare_responses():
# ----> 2     comparison_response = my_client.chat.completions.create(
#       3         model="gpt-5-nano",
#       4         messages=[
#       5             {"role": "system", "content": '''You are an evaluator. Please evaluate the quality of the response by different models.
#       6             Put as a JSON response with keys as model names and values as score out of 10. Also add a justification for the score.'''},
#       7             {"role": "user", "content": "Local LLM response: " + response_local_llm
#       8             +"\n\nOpenAI GPT-4.1 response: " + response_open_ai_41
#       9             + "\n\nOpenAI GPT-5 response: " + response_open_ai_5 }
#      10         ]
#      11     )
#      12     return comparison_response.choices[0].message.content
#
# NameError: name 'my_client' is not defined

# %%
print(f"{response_local_llm}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(f"{response_local_llm}")
#
# NameError: name 'response_local_llm' is not defined

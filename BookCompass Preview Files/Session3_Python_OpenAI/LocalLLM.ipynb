# %% [markdown]
# LLama 3 is SLM
# SLM vs LLM

# %% [markdown]
# distilling LLM
# scikit-learn.org

# %%
# %pip install ollama
# Out:
# Requirement already satisfied: ollama in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.6.2)
# Requirement already satisfied: httpx>=0.27 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ollama) (2.13.4)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx>=0.27->ollama) (4.13.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx>=0.27->ollama) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx>=0.27->ollama) (3.13)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.9->ollama) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.9->ollama) (0.4.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1
# [notice] To update, run: pip3.13 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import ollama
import time
client = ollama.Client()
client
user_input = input("What is your question? ")
prompt = user_input
start=time.time()
response = client.chat(
    model="llama3", #gpt-5-nano, gpt-5-mini, gpt-5, gpt-5-pro
    messages=[
        {"role": "system", "content": "You are a helpful assistant. Please answer clearly."}, # Single line with double quotes, if we have single line system prompt. If we have multi line system prompt, then we can use triple quotes.

        {"role": "user", "content": prompt}
    ]
)
end=time.time()
print(f"\n OLLAMA TIME  is : {end-start}")
#print (response.message.content)
# Out:
#  OLLAMA TIME  is : 9.664803981781006

# %%
import os
import time
import textwrap
from dotenv import load_dotenv
from openai import OpenAI
system_prompts = {'strict':'Yo are strict tutor',
                          'teacherlike' :'you are a teacher like tutor',
                          'friendly':'you are a friendly tutor',
                          'creative': 'you are a creative tutor'
                          }
load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")
#my_api_key[:5], my_api_key[-10:]
client = OpenAI(api_key=my_api_key)
#print (my_api_key)

def get_response_from_model(prompt, context):

    response = client.chat.completions.create(

        model="gpt-4.1-nano",
        messages=[
            {
                "role": "system", 
                "content": "{system_prompts.get(style,'teacherlike')}"
            },
            {
                "role": "user", 
                "content": f"Context information:\n{context}\n\nQuestion: {prompt}"
            }
        ]
    )

    return textwrap.fill(response.choices[0].message.content)


context = "I know. "
prompt = input("Ask something: ")

# Corrected function call
start=time.time()

response_text = get_response_from_model(prompt, context)
end=time.time()

print(f"\n gpt 4. TIME  is : {end-start}")

#print(f"\nOpenAI says: {response_text}")
# Out:
#  OLLAMA TIME  is : 18.283289670944214
